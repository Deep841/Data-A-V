# %% [markdown]
# ### Assignment - 3 :
# - Adventure Works Cycles dataset, including explanations and reasoning for each step :

# %%
# Step 1: Load Dataset and inspect

import pandas as pd 

#Load the coustomers and sales datasets 
df_customers = pd.read_csv('AWCustomers.csv')
df_sales = pd.read_csv('AWSales.csv')

#inspect columns and first few rows to understand data strucute.
print("coustomer cols : ",df_customers.columns)
print(df_customers.head(2))

print("\nsales cols : ", df_sales.columns)
print(df_sales.head(2))

#Reason : this step tells what data i hv & identify key cols, especially the target variable which indiated bike purchases.
# Out:
# coustomer cols :  Index(['CustomerID', 'Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix',
#        'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName',
#        'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate',
#        'Education', 'Occupation', 'Gender', 'MaritalStatus', 'HomeOwnerFlag',
#        'NumberCarsOwned', 'NumberChildrenAtHome', 'TotalChildren',
#        'YearlyIncome', 'LastUpdated'],
#       dtype='object')
#    CustomerID Title FirstName MiddleName LastName Suffix         AddressLine1  \
# 0       21173   NaN      Chad          C     Yuan    NaN   7090 C. Mount Hood
# 1       13249   NaN      Ryan        NaN    Perry    NaN  3651 Willow Lake Rd
#
#   AddressLine2        City StateProvinceName  ...        Education Occupation  \
# 0          NaN  Wollongong   New South Wales  ...        Bachelors   Clerical
# 1          NaN     Shawnee  British Columbia  ...  Partial College   Clerical
#
# ...

# %%
#Step 2: Create 'BikeBuyer' target variable

if 'ProductCategory' in df_sales.columns:
    df_bike_sales = df_sales[df_sales['ProductCategory'] == 'Bike']
else:
    df_bike_sales = df_sales
    

df_customers['BikeBuyer'] = df_customers['CustomerID'].isin(df_bike_sales['CustomerID']).astype(int)
# this creates the label/target needed for supervised learning and analysis, identifying who bought a bike.

# %%
#Step 3: Feature selection and data preprocessing
#(a)
